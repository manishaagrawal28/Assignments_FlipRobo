# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
#importing the libraries and warnings and setting warnings to ignore warnings

# %%
#loading dataset and providing names to the column
heart_data=pd.read_csv("cardio_train.csv",delimiter=";")

# %%
#loading the data into a DataFrame and checking the head of the data
heart_data=pd.DataFrame(heart_data)
heart_data.head()
# Out:
#     id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  988  22469       1     155    69.0    130     80            2     2      0
# 1  989  14648       1     163    71.0    110     70            1     1      0
# 2  990  21901       1     165    70.0    120     80            1     1      0
# 3  991  14549       2     165    85.0    120     80            1     1      1
# 4  992  23393       1     155    62.0    120     80            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       1       0
# 3     1       1       0
# 4     0       1       0

# %%
#datatypes of the column in the dataset
heart_data.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %%
# checking the shape of the data
heart_data.shape
# Out:
# (69301, 13)

# %%
#no null values present in the dataset
heart_data.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
#no null values present in the dataset
sns.heatmap(heart_data.isnull())

# %%
#droping NaN values
heart_data.dropna(inplace=True)

# %%
#statistical description of individual column
heart_data.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  69301.000000  69301.000000  69301.000000  69301.000000  69301.000000
# mean   50471.480397  19468.786280      1.349519    164.362217     74.203027
# std    28563.100347   2467.261818      0.476821      8.205337     14.383469
# min      988.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25745.000000  17664.000000      1.000000    159.000000     65.000000
# 50%    50494.000000  19704.000000      1.000000    165.000000     72.000000
# 75%    75150.000000  21326.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  69301.000000  69301.000000  69301.000000  69301.000000  69301.000000
# mean     128.829584     96.650092      1.366806      1.226447      0.088051
# ...

# %%
#the count of different types of prediction
print(heart_data.groupby('cardio').size())
# Out:
# cardio
# 0    34679
# 1    34622
# dtype: int64

# %%
#histogram of the individual column 
heart_data.hist(layout=(3,5),figsize=(20,20),bins=10)
plt.tight_layout()

# %%
#boxplot of individual column shows outliers in most of the  column
heart_data.plot(kind='box', subplots=True, layout=(5,6), sharex=False, sharey=False,figsize=(20,20))
plt.tight_layout()

# %%
#correlation matrix of the columns present in the dataset shows minimal correlation of column
heart_data.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003587  0.003773 -0.003735 -0.001549  0.003268
# age          0.003587  1.000000 -0.023150 -0.081304  0.054409  0.020663
# gender       0.003773 -0.023150  1.000000  0.499373  0.155649  0.005980
# height      -0.003735 -0.081304  0.499373  1.000000  0.290333  0.005492
# weight      -0.001549  0.054409  0.155649  0.290333  1.000000  0.030665
# ap_hi        0.003268  0.020663  0.005980  0.005492  0.030665  1.000000
# ap_lo       -0.002757  0.017717  0.015396  0.006215  0.043652  0.015919
# cholesterol  0.006400  0.154343 -0.036335 -0.050632  0.141901  0.023573
# gluc         0.002543  0.099095 -0.021154 -0.018929  0.107255  0.011821
# smoke       -0.003294 -0.047680  0.337608  0.187899  0.068304 -0.000933
# alco         0.000384 -0.029435  0.171015  0.094164  0.067259  0.001385
# active       0.002700 -0.009926  0.006241 -0.005974 -0.016514  0.000032
# ...

# %%
#heatmap showing the correlation between the various column has minimum correlation
plt.figure(figsize=(10,10))
sns.heatmap(heart_data.corr(),annot=True)
plt.tight_layout()

# %%
#pair plotting of each of the column shows most column dont vary with each other
sns.pairplot(heart_data)

# %%
scatter_matrix(heart_data,figsize=(20,20))
plt.show()

# %%
# voilin plot shows that most of the age group
sns.violinplot(heart_data["age"])

# %%
#jointplot of the age and the status
sns.jointplot(x="age",y="cardio",data=heart_data)

# %%
#jointplot of the height and the status
sns.jointplot(x="height",y="cardio",data=heart_data)

# %%
#jointplot of gender and status
sns.jointplot(x="gender",y="cardio",data=heart_data)

# %%
#shows the skewness in age column
sns.distplot(heart_data["age"])

# %%
#shows the skewness in weight column
sns.distplot(heart_data["weight"])

# %%
#skewness in height column
sns.distplot(heart_data["height"])

# %%
#countplot of the cardio column shows the no. of prediction for each type
sns.countplot(heart_data["cardio"])

# %%
sns.barplot(x="cardio",y="gender",data=heart_data)

# %%
heart_data.drop("id",inplace=True,axis=1)

# %%
heart_data.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  22469       1     155    69.0    130     80            2     2      0
# 1  14648       1     163    71.0    110     70            1     1      0
# 2  21901       1     165    70.0    120     80            1     1      0
# 3  14549       2     165    85.0    120     80            1     1      1
# 4  23393       1     155    62.0    120     80            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       1       0
# 3     1       1       0
# 4     0       1       0

# %%
#dividing the data into input
x=heart_data.iloc[:,:11]
x.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  22469       1     155    69.0    130     80            2     2      0
# 1  14648       1     163    71.0    110     70            1     1      0
# 2  21901       1     165    70.0    120     80            1     1      0
# 3  14549       2     165    85.0    120     80            1     1      1
# 4  23393       1     155    62.0    120     80            1     1      0
#
#    alco  active
# 0     0       1
# 1     0       1
# 2     0       1
# 3     1       1
# 4     0       1

# %%
#output data
y=heart_data.iloc[:,-1]
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: cardio, dtype: int64

# %%
#scaling of the input data
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.model_selection import GridSearchCV

# %%
#dividing the data into training and testing data
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2,stratify=y)

# %%
#importing the algorithms
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier

# %%
#creating object file of the algorithm
knn=KNeighborsClassifier()
sv=SVC()
dt=DecisionTreeClassifier(random_state=6)
lr=LogisticRegression()
rf=RandomForestClassifier()

# %%
#using GridSearchCV to find the best parameters for hyperparameter tuning
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from sklearn.model_selection import GridSearchCV
neighbors={"n_neighbors":range(1,30)}
gknn=GridSearchCV(knn,neighbors,cv=10)
gknn.fit(x,y)
gknn.best_params_
# Out:
# {'n_neighbors': 27}

# %%
#using GridSearchCV to find the best parameters for hyperparameter tuning
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
grid_param={"random_state":range(0,20),"criterion":['gini','entropy']}
Gdt=GridSearchCV(dt,param_grid=grid_param,scoring='accuracy',cv=10)
Gdt.fit(x,y)
Gdt.best_params_
# Out:
# {'criterion': 'entropy', 'random_state': 19}

# %%
#using GridSearchCV to find the best parameters for hyperparameter tuning
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
kernel={"kernel":["linear","rbf","poly"]}
Gsv=GridSearchCV(sv,kernel,cv=10)
Gsv.fit(x,y)
Gsv.best_params_
# Out:
# {'kernel': 'rbf'}

# %%
#using GridSearchCV to find the best parameters for hyperparameter tuning
from sklearn.ensemble import AdaBoostClassifier
ada_class=AdaBoostClassifier()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lr,dt]}
clf=GridSearchCV(ada_class,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=6, splitter='best'),
#  'learning_rate': 0.1,
#  'n_estimators': 1000}

# %%
#providing the parameters to the algorithm
knn=KNeighborsClassifier(n_neighbors=27)
sv=SVC(kernel="linear")
dt=DecisionTreeClassifier(random_state=19,criterion="entropy")
lr=LogisticRegression()
rf=RandomForestClassifier()
ada_class=AdaBoostClassifier(base_estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
                        max_depth=None, max_features=None, max_leaf_nodes=None,
                        min_impurity_decrease=0.0, min_impurity_split=None,
                        min_samples_leaf=1, min_samples_split=2,
                        min_weight_fraction_leaf=0.0, presort='deprecated',
                        random_state=6, splitter='best'),
 learning_rate=0.1,
 n_estimators=1000)

# %%
models=[]
models.append(("KNeighborsClassifier",knn))
models.append(("SVC",sv))
models.append(("DecisionTreeClassifier",dt))
models.append(("LogisticRegression",lr))
models.append(("RandomForestClassifier",rf))
models.append(("ADABoostClassifier",ada_class))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
Model=[]
score=[]
cvs=[]
roc_score=[]
for name,model in models:
    print('*********************',name,'***************************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print("accuracy_score",AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring="accuracy").mean()
    print("cross_val_score=",sc)
    cvs.append(sc*100)
    false_positive_rate,true_positive_rate,threshold=roc_curve(y_test,pre)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print("roc_auc_score=",roc_auc)
    roc_score.append(roc_auc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print("\n")
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC=%0.2f'%roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True positive rate')
    plt.xlabel('False positive rate')
    print('\n\n')
# Out:
# ********************* KNeighborsClassifier ***************************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=27, p=2,
#                      weights='uniform')
#
#
# accuracy_score 0.6679171776928071
#
#
# cross_val_score= 0.6701202848194624
# roc_auc_score= 0.6678943533242558
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.66      0.70      0.68      6936
#            1       0.68      0.64      0.66      6925
#
#     accuracy                           0.67     13861
#    macro avg       0.67      0.67      0.67     13861
# weighted avg       0.67      0.67      0.67     13861
#
#
#
# [[4832 2104]
#  [2499 4426]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ********************* SVC ***************************
#
#
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
# ...

# %%
result=pd.DataFrame({'Model':Model,'Accuracy_score':score,'Cross_Val_Score':cvs,"auc_roc":roc_score})
result
# Out:
#                     Model  Accuracy_score  Cross_Val_Score    auc_roc
# 0    KNeighborsClassifier       66.791718        67.012028  66.789435
# 1                     SVC       71.820215        72.306325  71.813464
# 2  DecisionTreeClassifier       63.314335        63.749447  63.314146
# 3      LogisticRegression       71.365702        72.086991  71.362507
# 4  RandomForestClassifier       70.968906        71.473717  70.968040
# 5      ADABoostClassifier       64.035784        67.534374  64.035984

# %%
from sklearn.externals import joblib
joblib.dump(sv,"sv_heartdisease.pkl")
# Out:
# ['sv_heartdisease.pkl']

# %% [markdown]
# # since the highest accuracy i.e 71.82% is provided by the support vector classifier and the cross_val_score is also the highest at 72.30% and auc-roc score of 71% so it is appropiate to choose support vector classifier
